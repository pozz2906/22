# %% [markdown]
# <a href="https://colab.research.google.com/github/pozz2906/22/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb >/dev/null 2>&1 || true
# !cloudflared --version
# Out:
# cloudflared version 2025.9.1 (built 2025-09-22-13:28 UTC)

# %%
# !nohup jupyter notebook \
  --allow-root \
  --no-browser \
  --ip=0.0.0.0 \
  --port=8888 \
  --NotebookApp.port_retries=0 \
  --NotebookApp.allow_origin='*' \
  --NotebookApp.allow_remote_access=True \
  > /content/jupyter.log 2>&1 &

# !sleep 3 && tail -n 40 /content/jupyter.log
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# [I 13:09:48.664 NotebookApp] Writing notebook server cookie secret to /root/.local/share/jupyter/runtime/notebook_cookie_secret
# [I 13:09:48.961 NotebookApp] Loading IPython parallel extension
# [I 13:09:49.055 NotebookApp] [Jupytext Server Extension] Deriving a TextFileContentsManager from LargeFileManager

# %%
# !grep -oP 'token=\K[0-9a-f]+' /content/jupyter.log | tail -n1
# Out:
# a73847cadd72fc7ffb56b5d026eb2705f966dd2b908477f6

# %%
# !nohup cloudflared tunnel --url http://localhost:8888 --no-autoupdate > /content/cloudflared.log 2>&1 &
# !sleep 4
# !grep -oP 'https://[a-z0-9-]+\.trycloudflare\.com' /content/cloudflared.log | tail -n1
# Out:
# https://icon-ranges-ana-wool.trycloudflare.com
